# %%
#19101185 강동현 데이터분석 과제 Assignment 05
#a번문제 - 카시트 데이터를 multiple regression model을 통해 Sales를 Price,
#Urban, and US로 추정하는 문제이다.

# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import statsmodels.formula.api as smf

Carseats = pd.read_csv('C:\\Users\\car99\\Carseats.csv', index_col=0)


ols_smf = smf.ols(formula='Sales ~ Price + Urban + US', data=Carseats)


ols_smf_results = ols_smf.fit()
ols_smf_results.summary()

#b번문제 - 각 요소들의 coefficient를 해석하는 문제이다. 이 경우 정성적인 변수들 또한 존재한다.
#따라서 우리는 t-statistic의 p-value를 통해 coefficient 해석이 가능하다. coefficient가 음수인 경우
#판매량과 반대의 성질을 가진다고 볼 수 있다. 예를 들어 가격 즉 Price의 경우는 -0.0545 이므로 
#가격이 증가할 수록 판매량이 증가한다고 볼 수 있다. 이 역시 생각해보면 당연한 결과로 우리는 
#coefficient와 Sales의 관계를 이해할 수 있다. 그런 의미에서 US는 Sales와 같은 성질임을 알 수 있다.
#또한 Urban의 경우 p-value가 상당히 크므로 Urban은 판매량과 무관하다고 해석 할 수 있다.
#(문제에서는 qualitative한 변수들 즉 Urban과 US가 있다. 이 경우 아래 표에서는 두 항목에 대하여
#Yes의 경우를 다루고 있다. 따라서 위쪽에서 다룬 Urban과 Us도 Yes에 관한 내용이다.)



#c번문제 - 우리가 구한 모델을 수학적인 식으로 표현하는 문제이다. 따라서 식을 위의 자료를 참고해 작성하면
# Y(판매량) = 13.0435 + 1.2006US[Yes] - 0.0219Urban[Yes] - 0.0545Price 이다.



#d번문제 - null hypothesis를 거부 할 수 있는 predictor를 물어보는 문제이다. 이경우 H0 = 베타j가 0인 경우이다.
#우리는 위쪽에서 Urban[Yes]가 판매량과는 큰 의미가 없다는 사실을 알았다. 따라서 우리는 H0를 거부할 수 있는 
#Predictor로 Urban[Yes]을 제외한 나머지 즉 US[Yes]와 Price를 사용할 수 있다. 이때 우리는 이 각각의 Predictor에 
#대해서 p-value와 F-statistic 그리고 F-statistic에 대한 p-value를 사용할 수 있다.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.234
# Method:                 Least Squares   F-statistic:                     41.52
# Date:                Fri, 09 Apr 2021   Prob (F-statistic):           2.39e-23
# Time:                        02:37:31   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1863.
# Df Residuals:                     396   BIC:                             1879.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
#e번문제 - 따라서 우리는 지금까지의 결과들로 더 작은 모델을 만들 수 있다. 문제는 의미있는 결과를 내는
#더 작은 모델을 만드는 문제이다.따라서 우리는 위에서 보았듯이 의미가 있는 Predictor들인 US와 Price만을 이용하여
#모델을 만들 수 있다. 따라서 아래처럼 US[Yes]와 Price만을 Predictor로 가지는 더 작은 모델이 나올 수 있다.

ols_smf2 = smf.ols(formula='Sales ~ Price + US', data=Carseats)


ols_smf2_results = ols_smf2.fit()
ols_smf2_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Sales   R-squared:                       0.239
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     62.43
# Date:                Fri, 09 Apr 2021   Prob (F-statistic):           2.66e-24
# Time:                        02:56:46   Log-Likelihood:                -927.66
# No. Observations:                 400   AIC:                             1861.
# Df Residuals:                     397   BIC:                             1873.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     13.0308      0.631     20.652      0.000      11.790      14.271
# ...
